# %%
Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
it is a specified obsereved numerical value used to estimate unknown population parameter.
point:it is a single value used to estimate an unknown population parameter.
interval:range of value used to estimate the unknown population parameter

# %%
Q2. Write a Python function to estimate the population mean using a sample mean and standard
deviation.

# %%
def poplation_mean(sample_mean,sample_Std):
    standard_error = sample_std / math.sqrt(sample_size)
    margin_of_error = 1.96 * standard_error
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error
    print("Population mean: ", lower_bound, " to ", upper_bound)

# %%
Q3: What is Hypothesis testing? Why is it used? State the importance of Hypothesis testing.
it is a intertial stats used to make decision.
it is used to make conculsions wheather to reject or accept the hypothesis
hypothesis testing is an important for making evidence-based decisions and ensuring that results are reliable and trustworthy.

# %%
Q4. Create a hypothesis that states whether the average weight of male college students is greater than
the average weight of female college students.

# %%
null hypothesis: mean_male < mean_female
alternate_hypothesis: mean_male > mean_female

# %%
Q6: What is a null and alternative hypothesis? Give some examples.
null hypothesis is assumption of hypothesis we are begining with.
example: μ1=μ2
alternate hypot hesis is opposite to null hypothesis
example: μ1!=μ2

# %%
Q7: Write down the steps involved in hypothesis testing.
1-null hypothesis 
2-alternate hypothesis
3-statics analysis 
4-conculsion(reject/fail to reject)

# %%
Q8. Define p-value and explain its significance in hypothesis testing.
the probability under the assumption of no effect or no difference (null hypothesis), 
of obtaining a result equal to or more extreme than what was actually observed. 
its signifiance is how likely it is that any observed difference between groups is due to chance.

# %%
Q9.Generate a Student's t-distribution plot using Python's matplotlib library, with the degrees of freedom
parameter set to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import t
df = 10
x = np.linspace(-4, 4, 1000)
y = t.pdf(x, df)
plt.plot(x, y)
plt.title("Student's t-distribution (df=10)")
plt.xlabel('x')
plt.ylabel('Probability density')
plt.show()

# %%
Q10. Write a Python program to calculate the two-sample t-test for independent samples, given two
random samples of equal size and a null hypothesis that the population means are equal.

# %%
import numpy as np
from scipy.stats import ttest_ind
sample1 = np.random.normal(10, 2, 50)
sample2 = np.random.normal(12, 2, 50)
null_hypothesis = "The population means are equal"
t_statistic, p_value = ttest_ind(sample1, sample2)
print("Null hypothesis:", null_hypothesis)
print("Sample 1 mean:", np.mean(sample1))
print("Sample 2 mean:", np.mean(sample2))
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# Null hypothesis: The population means are equal
# Sample 1 mean: 10.552472776789646
# Sample 2 mean: 11.770162435082831
# T-statistic: -2.9074393145184603
# P-value: 0.004507006448822445

# %%
Q11: What is Student’s t distribution? When to use the t-Distribution.
it is similar to normal disturbution has a symmertic and bell sahped curve but has a heaiver tail
in z-test we perform using z-score and standard deviation but when standard deivation is not known then 
we use Student’s t distribution

# %%
Q12: What is t-statistic? State the formula for t-statistic.
The t-statistic is a measure used in hypothesis testing to determine whether the mean of two groups
is significantly different from each other, given a sample from each group
t = (x1 - x2) / (s / sqrt(n))
x1 is the sample mean of the first group
x2 is the sample mean of the second group
s is the pooled standard deviation of the two groups
n is the total sample size (number of observations in both groups combined)

# %%
Q13. A coffee shop owner wants to estimate the average daily revenue for their shop. They take a random
sample of 50 days and find the sample mean revenue to be $500 with a standard deviation of $50.
Estimate the population mean revenue with a 95% confidence interval.
x̄ = 500
t(α/2, n-1)=2.010
s=50
n=50
CI = x̄ ± t(α/2, n-1) * (s/√n)
lower ci=500 - 2.009 * (50/√50)=485.86 
upper ci=500 + 2.009 * (50/√50)=514.14

# %%
Q14. A researcher hypothesizes that a new drug will decrease blood pressure by 10 mmHg. They conduct a
clinical trial with 100 patients and find that the sample mean decrease in blood pressure is 8 mmHg with a
standard deviation of 3 mmHg. Test the hypothesis with a significance level of 0.05.
alpha=0.05 and df=n-1=100-1=99
from T-table cv=-1.066
t = (x̄ - μ) / (s / √n)
t = (8 - 10) / (3 / √100) =-2.82
conculsion=-2.82>-1.066, reject the hypothesis

# %%
Q15. An electronics company produces a certain type of product with a mean weight of 5 pounds and a
standard deviation of 0.5 pounds. A random sample of 25 products is taken, and the sample mean weight
is found to be 4.8 pounds. Test the hypothesis that the true mean weight of the products is less than 5
pounds with a significance level of 0.01.
x̄=4.8
μ=5,std=0.5,n=25
alpha=0.01 and df=n-1=25-1=24
from T-table cv=-2.492
t = (x̄ - μ) / (s / √n)
t = (4.8 - 5) / (0.5 / √25) = -2
conculsion=-2.492>-2, reject the hypothesis

# %%
Q16. Two groups of students are given different study materials to prepare for a test. The first group (n1 =
30) has a mean score of 80 with a standard deviation of 10, and the second group (n2 = 40) has a mean
score of 75 with a standard deviation of 8. Test the hypothesis that the population means for the two
groups are equal with a significance level of 0.01.
alpha=0.01 and dof=n1-1+n2-1=30-1+40-1=68
from T-table cv= -2.66 and 2.66
t = (x̄1 - x̄2) / sqrt[s1^2/n1 + s2^2/n2]
t = (80 - 75) / sqrt[(10^2/30) + (8^2/40)] = 2.25
conculsion=-2.66<2.25<2.66
since 2.25 is in between of -2.66 and 2.66,we fail to reject

# %%
Q17. A marketing company wants to estimate the average number of ads watched by viewers during a TV
program. They take a random sample of 50 viewers and find that the sample mean is 4 with a standard
deviation of 1.5. Estimate the population mean with a 99% confidence interval.
CI = x̄ ± z*(s / sqrt(n))
CI = 4 - 2.576*(1.5 / sqrt(50))=3.32
CI = 4 + 2.576*(1.5 / sqrt(50))=4.68
conculsion= i am 99% confident that the popuation mean lies between (3.32,4.68)
